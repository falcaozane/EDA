# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("shopping_trends.csv")

# %%
data.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#   Payment Method  Shipping Type Discount Applied Promo Code Used  \
# 0    Credit Card        Express              Yes             Yes
# 1  Bank Transfer        Express              Yes             Yes
# 2           Cash  Free Shipping              Yes             Yes
# 3         PayPal   Next Day Air              Yes             Yes
# 4           Cash  Free Shipping              Yes             Yes
#
#    Previous Purchases Preferred Payment Method Frequency of Purchases
# 0                  14                    Venmo            Fortnightly
# 1                   2                     Cash            Fortnightly
# 2                  23              Credit Card                 Weekly
# 3                  49                   PayPal                 Weekly
# 4                  31                   PayPal               Annually

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
#  13  Shipping Type             3900 non-null   object
#  14  Discount Applied          3900 non-null   object
#  15  Promo Code Used           3900 non-null   object
#  16  Previous Purchases        3900 non-null   int64
#  17  Preferred Payment Method  3900 non-null   object
#  18  Frequency of Purchases    3900 non-null   object
# dtypes: float64(1), int64(4), object(14)
# memory usage: 579.0+ KB

# %%
data.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
data.shape
# Out:
# (3900, 19)

# %%
data.isna().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3895    False
# 3896    False
# 3897    False
# 3898    False
# 3899    False
# Length: 3900, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data["Age"].plot(kind='hist')
plt.title("Histogram")
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
data.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
data["Gender"].value_counts().plot(kind="bar")
plt.title("Barplot of Genger")
plt.show()

# %%
data.groupby("Category")["Purchase Amount (USD)"].mean()
# Out:
# Category
# Accessories    59.838710
# Clothing       60.025331
# Footwear       60.255426
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %%
data.groupby("Category")["Purchase Amount (USD)"].mean().sort_values(ascending=False)
# Out:
# Category
# Footwear       60.255426
# Clothing       60.025331
# Accessories    59.838710
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %%
data.groupby("Category")["Purchase Amount (USD)"].mean().sort_values(ascending=False).tail()
# Out:
# Category
# Footwear       60.255426
# Clothing       60.025331
# Accessories    59.838710
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %%
data.sort_values("Review Rating",ascending=False)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 776           777   49    Male          Shirt     Clothing
# 1664         1665   19    Male        Handbag  Accessories
# 1277         1278   19    Male         Blouse     Clothing
# 2632         2633   24    Male          Scarf  Accessories
# 965           966   43    Male          Boots     Footwear
# ...           ...  ...     ...            ...          ...
# 1451         1452   54    Male         Jacket    Outerwear
# 3473         3474   63  Female          Dress     Clothing
# 1449         1450   18    Male          Socks     Clothing
# 133           134   52    Male        Sweater     Clothing
# 870           871   66    Male         Hoodie     Clothing
#
#       Purchase Amount (USD)       Location Size     Color  Season  \
# 776                      60        Alabama    M    Maroon  Spring
# 1664                     53      Minnesota    M    Purple  Spring
# 1277                     97   Rhode Island    L     Green  Spring
# 2632                     27         Alaska    M     Black    Fall
# 965                      55       Delaware    L     Black  Spring
# ...                     ...            ...  ...       ...     ...
# 1451                     34           Utah    M    Maroon    Fall
# 3473                     40         Kansas    M      Cyan  Spring
# 1449                     41       New York    L  Lavender  Winter
# 133                      65        Montana    M    Violet  Winter
# 870                      66  West Virginia    M      Blue    Fall
#
#       Review Rating Subscription Status Payment Method Shipping Type  \
# 776             5.0                 Yes         PayPal      Standard
# 1664            5.0                  No         PayPal  Next Day Air
# 1277            5.0                  No     Debit Card       Express
# 2632            5.0                  No          Venmo  Next Day Air
# 965             5.0                 Yes     Debit Card  Store Pickup
# ...             ...                 ...            ...           ...
# 1451            2.5                  No          Venmo  Next Day Air
# 3473            2.5                  No    Credit Card       Express
# 1449            2.5                  No     Debit Card  Store Pickup
# 133             2.5                 Yes  Bank Transfer  Next Day Air
# 870             2.5                 Yes           Cash      Standard
#
#      Discount Applied Promo Code Used  Previous Purchases  \
# 776               Yes             Yes                   8
# 1664              Yes             Yes                  35
# 1277              Yes             Yes                   5
# 2632               No              No                  14
# 965               Yes             Yes                  10
# ...               ...             ...                 ...
# 1451              Yes             Yes                  35
# 3473               No              No                  11
# 1449              Yes             Yes                  20
# 133               Yes             Yes                  25
# 870               Yes             Yes                   6
#
#      Preferred Payment Method Frequency of Purchases
# 776                     Venmo         Every 3 Months
# 1664                   PayPal                 Weekly
# 1277                    Venmo              Quarterly
# 2632                     Cash               Annually
# 965               Credit Card               Annually
# ...                       ...                    ...
# 1451                   PayPal              Quarterly
# 3473                     Cash                 Weekly
# 1449                     Cash         Every 3 Months
# 133                     Venmo               Annually
# 870             Bank Transfer              Bi-Weekly
#
# [3900 rows x 19 columns]

# %%
data.sort_values("Review Rating",ascending=False, inplace=True)

# %%
data["Subscription Status"].value_counts().plot(kind="pie")
plt.title("Pie chart of Subscription")
plt.show()

# %%
data["Color"].value_counts()
# Out:
# Color
# Olive        177
# Yellow       174
# Silver       173
# Teal         172
# Green        169
# Black        167
# Violet       166
# Cyan         166
# Gray         159
# Maroon       158
# Orange       154
# Pink         153
# Charcoal     153
# Blue         152
# Magenta      152
# Purple       151
# Peach        149
# Red          148
# Lavender     147
# Indigo       147
# Beige        147
# Turquoise    145
# White        142
# Brown        141
# Gold         138
# Name: count, dtype: int64

# %%
data["Color"].value_counts().head().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
data.plot(x="Previous Purchases", y="Review Rating", kind="scatter")
plt.title("Scatter plot - previous purchases review ratings")
plt.show()

# %%
data.head(10).plot(x="Previous Purchases", y="Review Rating", kind="scatter")
plt.title("Scatter plot - previous purchases review ratings")
plt.show()

# %%
data.head(75).plot(x="Previous Purchases", y="Review Rating", kind="scatter")
plt.title("Scatter plot - previous purchases review ratings")
plt.show()

# %%
pd.pivot_table(data, values="Purchase Amount (USD)", index="Location", columns="Item Purchased", aggfunc="mean")
# Oklahoma        39.000000  45.800000   37.250000  20.000000  81.250000
# Oregon          53.000000  59.833333   80.333333  71.000000  66.250000
# Pennsylvania    74.250000  61.500000   63.750000  65.000000  72.500000
# Rhode Island    65.000000  38.000000   41.000000  62.250000  66.000000
# South Carolina  88.000000  28.000000   84.000000  42.000000  23.000000
# South Dakota    49.000000  52.800000   80.333333  61.000000  43.500000
# Tennessee       55.666667  47.000000   82.500000  67.333333  48.250000
# Texas           74.666667  35.000000   67.200000  71.250000  88.333333
# Utah            60.500000  33.000000   42.333333  59.000000  82.000000
# Vermont         55.285714  68.000000   45.000000  47.142857  48.200000
# Virginia        73.666667  33.666667   33.333333  58.000000  67.500000
# Washington      73.000000  52.857143   63.000000  40.000000  45.333333
# West Virginia   67.000000        NaN   61.125000  82.000000  67.750000
# Wisconsin       37.666667  54.000000   44.666667  52.000000  59.000000
# Wyoming         62.500000  32.000000   67.000000  29.500000  73.000000
#
# [50 rows x 25 columns]

# %%
pd.pivot_table(data, values="Purchase Amount (USD)", index="Location", columns="Item Purchased", aggfunc="mean").head()
# Out:
# Item Purchased  Backpack       Belt  Blouse      Boots       Coat      Dress  \
# Location
# Alabama             74.0  26.500000    52.0  73.666667  54.500000  55.200000
# Alaska              74.6  76.750000    67.5  56.000000  45.500000  74.500000
# Arizona             48.6  84.500000    61.0        NaN  65.333333  71.000000
# Arkansas            90.0  55.000000    66.0  50.000000  54.250000  62.800000
# California          57.4  61.666667    39.5  62.500000  55.000000  58.428571
#
# Item Purchased     Gloves    Handbag        Hat     Hoodie  ...      Scarf  \
# Location                                                    ...
# Alabama         85.000000  57.666667  76.000000  53.000000  ...  75.333333
# Alaska          66.333333  46.000000  52.666667  56.500000  ...  45.000000
# Arizona         87.000000  58.666667  87.000000  66.666667  ...  53.500000
# Arkansas        64.333333  50.000000  35.000000  55.250000  ...  67.500000
# California      53.000000  65.250000  49.000000  56.000000  ...  54.500000
#
# Item Purchased  Shirt      Shoes     Shorts      Skirt   Sneakers  Socks  \
# Location
# Alabama          48.2  54.333333  49.000000  68.666667  79.500000  93.50
# Alaska           59.5  80.000000  76.666667  87.333333  73.333333  74.25
# Arizona          80.0  87.000000  46.000000  68.500000  78.500000  61.00
# Arkansas         59.0  59.500000  95.000000  44.500000  69.000000  60.50
# California       42.8        NaN  63.333333  56.000000  73.000000  83.00
#
# Item Purchased  Sunglasses    Sweater  T-shirt
# Location
# Alabama          62.666667  40.500000    52.50
# Alaska           83.000000  50.333333    56.75
# Arizona          66.000000  70.400000    62.00
# Arkansas         56.000000  71.500000    52.00
# California       69.400000  42.000000    69.00
#
# [5 rows x 25 columns]

# %%
data.groupby("Size")["Purchase Amount (USD)"].mean()
# Out:
# Size
# L     58.563153
# M     59.924217
# S     61.037707
# XL    60.090909
# Name: Purchase Amount (USD), dtype: float64

# %%
data.groupby("Payment Method")["Purchase Amount (USD)"].sum()
# Out:
# Payment Method
# Bank Transfer    37123
# Cash             38833
# Credit Card      42567
# Debit Card       37118
# PayPal           37449
# Venmo            39991
# Name: Purchase Amount (USD), dtype: int64

# %%
data.groupby("Discount Applied")["Review Rating"].mean()
# Out:
# Discount Applied
# No     3.757715
# Yes    3.739654
# Name: Review Rating, dtype: float64

# %%
data.groupby("Color")["Category"].value_counts()
# Out:
# Color   Category
# Beige   Clothing       65
#         Accessories    44
#         Footwear       24
#         Outerwear      14
# Black   Clothing       81
#                        ..
# White   Outerwear      15
# Yellow  Clothing       75
#         Accessories    56
#         Footwear       30
#         Outerwear      13
# Name: count, Length: 100, dtype: int64

# %%
data.groupby("Frequency of Purchases")["Previous Purchases"].median()
# Out:
# Frequency of Purchases
# Annually          24.0
# Bi-Weekly         24.0
# Every 3 Months    24.0
# Fortnightly       26.0
# Monthly           25.0
# Quarterly         28.0
# Weekly            26.0
# Name: Previous Purchases, dtype: float64

# %%
data.groupby("Season")["Review Rating"].mean()
# Out:
# Season
# Fall      3.729949
# Spring    3.790591
# Summer    3.725654
# Winter    3.752111
# Name: Review Rating, dtype: float64

# %%
data["Season"].value_counts().plot(kind="bar")
plt.xlabel("Season")
plt.ylabel("Count")
plt.title("Count of Purchases in each season")
plt.show()

# %%
data["Category"].value_counts().plot(kind="pie")
plt.title("Distribution of Purchases by Category")
plt.show()

# %%
data.boxplot(column="Review Rating", by="Gender")
plt.xlabel("Gender")
plt.ylabel("Review Rating")
plt.title("Review Rating Distribution By Gender")
plt.show()

# %%
data["Purchase Amount (USD)"].plot(kind="hist",bins=10)
plt.xlabel("USD")
plt.ylabel("Frequency")
plt.title("Histogram of Purchases Amount Distribution")
plt.show()

# %%
data.groupby("Color")["Review Rating"].mean().plot(kind="bar")
plt.xlabel("Color")
plt.ylabel("Mean Review Rating")
plt.title("Mean Review for each Color")
plt.show()

# %%
data.groupby("Payment Method")["Purchase Amount (USD)"].sum().plot(kind="pie")
plt.title("Sum of Purchase Amount by Payment Method")
plt.xlabel("")
plt.ylabel("")
plt.show()

# %%
data.boxplot(column="Purchase Amount (USD)", by="Frequency of Purchases")
plt.xlabel("Frequency of Purchases")
plt.ylabel("Purchase Amount (USD)")
plt.title("Purchase Amount Distribution by frequency of purchases")
plt.show()

# %%
data.groupby("Season")["Purchase Amount (USD)"].median().plot(kind="pie")
plt.xlabel("Season")
plt.ylabel("Sum of Purchases Amount (USD)")
plt.title("Sum of Purchase Amount by Season")
plt.show()

# %%
data.groupby("Season")["Purchase Amount (USD)"].mean().plot(kind="pie")
plt.xlabel("Season")
plt.ylabel("Sum of Purchases Amount (USD)")
plt.title("Sum of Purchase Amount by Season")
plt.show()

# %%
data.groupby("Season")["Purchase Amount (USD)"].max().plot(kind="pie")
plt.xlabel("Season")
plt.ylabel("Sum of Purchases Amount (USD)")
plt.title("Sum of Purchase Amount by Season")
plt.show()

# %%
data.groupby("Season")["Purchase Amount (USD)"].min().plot(kind="pie")
plt.xlabel("Season")
plt.ylabel("Sum of Purchases Amount (USD)")
plt.title("Sum of Purchase Amount by Season")
plt.show()
